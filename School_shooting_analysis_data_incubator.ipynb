# %%
import pandas as pd
import numpy as np
import matplotlib

# %% [markdown]
# Data taken from Washington Post website: https://www.washingtonpost.com/graphics/2018/local/school-shootings-database/?utm_term=.4452c91548ea

# %%
df_data = pd.read_csv('school-shootings-data.csv')

# %%
df_data.head()
# Out:
#    uid nces_school_id                  school_name  nces_district_id  \
# 0    1   080480000707        Columbine High School          804800.0
# 1    2   220054000422  Scotlandville Middle School         2200540.0
# 2    3   130441001591         Heritage High School         1304410.0
# 3    4   421899003847     John Bartram High School         4218990.0
# 4    5   250279000225       Dorchester High School         2502790.0
#
#                           district_name       date school_year  year  \
# 0                  Jefferson County R-1  4/20/1999   1998-1999  1999
# 1  East Baton Rouge Parish School Board  4/22/1999   1998-1999  1999
# 2                       Rockdale County  5/20/1999   1998-1999  1999
# 3                  Philadelphia City SD  10/4/1999   1999-2000  1999
# 4                                Boston  11/3/1999   1999-2000  1999
#
#        time day_of_week   ...          lat        long staffing low_grade  \
# 0  11:19 AM     Tuesday   ...    39.603910 -105.075000     89.6         9
# 1  12:30 PM    Thursday   ...    30.529958  -91.169966     39.0         6
# 2   8:03 AM    Thursday   ...    33.626922  -84.047960     84.0         9
# 3  10:00 AM      Monday   ...    39.921509  -75.234108     41.0         9
# 4   7:40 AM   Wednesday   ...    42.285268  -71.075901      NaN         9
#
#    high_grade   lunch                   county state_fips  county_fips ulocale
# 0          12    41.0         Jefferson County          8         8059    21.0
# 1           8   495.0  East Baton Rouge Parish         22        22033    12.0
# 2          12   125.0          Rockdale County         13        13247    21.0
# 3          12  2007.0      Philadelphia County         42        42101    11.0
# 4          12   543.0           Suffolk County         25        25025    11.0
#
# [5 rows x 50 columns]

# %%
df_data.columns
# Out:
# Index(['uid', 'nces_school_id', 'school_name', 'nces_district_id',
#        'district_name', 'date', 'school_year', 'year', 'time', 'day_of_week',
#        'city', 'state', 'school_type', 'enrollment', 'killed', 'injured',
#        'casualties', 'shooting_type', 'age_shooter1', 'gender_shooter1',
#        'race_ethnicity_shooter1', 'shooter_relationship1', 'shooter_deceased1',
#        'deceased_notes1', 'age_shooter2', 'gender_shooter2',
#        'race_ethnicity_shooter2', 'shooter_relationship2', 'shooter_deceased2',
#        'deceased_notes2', 'white', 'black', 'hispanic', 'asian',
#        'american_indian_alaska_native', 'hawaiian_native_pacific_islander',
#        'two_or_more', 'resource_officer', 'weapon', 'weapon_source', 'lat',
#        'long', 'staffing', 'low_grade', 'high_grade', 'lunch', 'county',
#        'state_fips', 'county_fips', 'ulocale'],
#       dtype='object')

# %%
df_data.groupby('school_type').count()
# Out:
#              uid  nces_school_id  school_name  nces_district_id  \
# school_type
# private       11               9           11                 0
# public       206             205          206               206
#
#              district_name  date  school_year  year  time  day_of_week  \
# school_type
# private                  0    11           11    11    11           11
# public                 206   206          206   206   195          206
#
#               ...     lat  long  staffing  low_grade  high_grade  lunch  \
# school_type   ...
# private       ...      10    10         9         11          11      0
# public        ...     206   206       190        204         204    192
#
#              county  state_fips  county_fips  ulocale
# school_type
# private          11          11           11       10
# public          206         206          206      206
#
# [2 rows x 49 columns]

# %%
df_data.groupby('shooting_type').count()
# Out:
#                              uid  nces_school_id  school_name  \
# shooting_type
# accidental                    26              26           26
# accidental or targeted         2               2            2
# hostage suicide                2               2            2
# indiscriminate                42              42           42
# public suicide                 4               4            4
# public suicide (attempted)     1               1            1
# targeted                     130             128          130
# targeted and indiscriminate    5               5            5
# unclear                        4               4            4
#
#                              nces_district_id  district_name  date  \
# shooting_type
# accidental                                 25             25    26
# accidental or targeted                      2              2     2
# hostage suicide                             2              2     2
# indiscriminate                             41             41    42
# public suicide                              3              3     4
# public suicide (attempted)                  1              1     1
# targeted                                  123            123   130
# targeted and indiscriminate                 5              5     5
# unclear                                     4              4     4
#
#                              school_year  year  time  day_of_week   ...     \
# shooting_type                                                       ...
# accidental                            26    26    23           26   ...
# accidental or targeted                 2     2     2            2   ...
# hostage suicide                        2     2     2            2   ...
# indiscriminate                        42    42    40           42   ...
# public suicide                         4     4     4            4   ...
# public suicide (attempted)             1     1     1            1   ...
# targeted                             130   130   124          130   ...
# targeted and indiscriminate            5     5     5            5   ...
# unclear                                4     4     4            4   ...
#
#                              lat  long  staffing  low_grade  high_grade  \
# shooting_type
# accidental                    26    26        24         26          26
# accidental or targeted         2     2         2          2           2
# hostage suicide                2     2         2          2           2
# indiscriminate                42    42        39         42          42
# public suicide                 4     4         4          4           4
# public suicide (attempted)     1     1         1          1           1
# targeted                     130   130       118        128         128
# targeted and indiscriminate    5     5         5          5           5
# unclear                        4     4         4          4           4
#
#                              lunch  county  state_fips  county_fips  ulocale
# shooting_type
# accidental                      22      26          26           26       26
# accidental or targeted           2       2           2            2        2
# hostage suicide                  2       2           2            2        2
# indiscriminate                  38      42          42           42       42
# public suicide                   3       4           4            4        4
# public suicide (attempted)       1       1           1            1        1
# targeted                       115     130         130          130      129
# targeted and indiscriminate      5       5           5            5        5
# unclear                          4       4           4            4        4
#
# [9 rows x 49 columns]

# %%
df_data.groupby('shooting_type').count()
# Out:
#                              uid  nces_school_id  school_name  \
# shooting_type
# accidental                    26              26           26
# accidental or targeted         2               2            2
# hostage suicide                2               2            2
# indiscriminate                42              42           42
# public suicide                 4               4            4
# public suicide (attempted)     1               1            1
# targeted                     130             128          130
# targeted and indiscriminate    5               5            5
# unclear                        4               4            4
#
#                              nces_district_id  district_name  date  \
# shooting_type
# accidental                                 25             25    26
# accidental or targeted                      2              2     2
# hostage suicide                             2              2     2
# indiscriminate                             41             41    42
# public suicide                              3              3     4
# public suicide (attempted)                  1              1     1
# targeted                                  123            123   130
# targeted and indiscriminate                 5              5     5
# unclear                                     4              4     4
#
#                              school_year  year  time  day_of_week   ...     \
# shooting_type                                                       ...
# accidental                            26    26    23           26   ...
# accidental or targeted                 2     2     2            2   ...
# hostage suicide                        2     2     2            2   ...
# indiscriminate                        42    42    40           42   ...
# public suicide                         4     4     4            4   ...
# public suicide (attempted)             1     1     1            1   ...
# targeted                             130   130   124          130   ...
# targeted and indiscriminate            5     5     5            5   ...
# unclear                                4     4     4            4   ...
#
#                              lat  long  staffing  low_grade  high_grade  \
# shooting_type
# accidental                    26    26        24         26          26
# accidental or targeted         2     2         2          2           2
# hostage suicide                2     2         2          2           2
# indiscriminate                42    42        39         42          42
# public suicide                 4     4         4          4           4
# public suicide (attempted)     1     1         1          1           1
# targeted                     130   130       118        128         128
# targeted and indiscriminate    5     5         5          5           5
# unclear                        4     4         4          4           4
#
#                              lunch  county  state_fips  county_fips  ulocale
# shooting_type
# accidental                      22      26          26           26       26
# accidental or targeted           2       2           2            2        2
# hostage suicide                  2       2           2            2        2
# indiscriminate                  38      42          42           42       42
# public suicide                   3       4           4            4        4
# public suicide (attempted)       1       1           1            1        1
# targeted                       115     130         130          130      129
# targeted and indiscriminate      5       5           5            5        5
# unclear                          4       4           4            4        4
#
# [9 rows x 49 columns]

# %%
df_data.hist(column = ['year'], figsize = (8,6), xlabelsize=13, ylabelsize =13)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efd70ccd550>]],
#       dtype=object)

# %%
df_data['hour'] = pd.DatetimeIndex(df_data['time']).hour
df_data.hist(column=['hour'], figsize = (8,6), xlabelsize=13, ylabelsize =13)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efd6e9a4eb8>]],
#       dtype=object)

# %% [markdown]
# ## Seasonality in frequence of shooting

# %% [markdown]
# ## School shooting: strong seasonality

# %%
df_data['month'] = pd.DatetimeIndex(df_data['date']).month

# %%
df_data.hist(column=['month'], bins = 12,figsize = (12,8), xlabelsize=13, ylabelsize =13)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efd6e798550>]],
#       dtype=object)

# %% [markdown]
# It can be seen that there is a strong seasonaity to shooting incidents. They are very high during January, February, Septemeber and October. A chi-square test will establish the statistical significance of the dependence of month

# %% [markdown]
# ## shooting type in school shootings: Targeted types have strong seasonality

# %%
df_data_cln_shoot_type = df_data.dropna(subset = ['shooting_type'],axis = 0)

# %%
df_data_cln_shoot_type[df_data_cln_shoot_type['shooting_type'].str.contains('targeted') == True].hist(column=['month'],bins =12, figsize = (12,8), xlabelsize=13, ylabelsize =13)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efd6e70f550>]],
#       dtype=object)

# %% [markdown]
# A large percentage of shootings seen in Jan, Feb, Sep and Oct is "targeted". This implies that these need some planning.

# %% [markdown]
# ### Chi-square test

# %%
dat_num = df_data.groupby('month').count()['uid']

# %%
from scipy.stats import chisquare

# %%
avg = [dat_num.sum()/ len(dat_num)]*12

# %%
print ("probability of the observed shooings to be independent of the month is ",chisquare(dat_num, avg)[1])
# Out:
# probability of the observed shooings to be independent of the month is  6.723162927917046e-12

# %% [markdown]
# ## Mass shooting: No seasonality

# %% [markdown]
# Data of all mass shootings ( which are indiscriminate in nature) show no seasonality. Data taken from Mother Jones website:  https://www.motherjones.com/politics/2012/12/mass-shootings-mother-jones-full-data/

# %%
df_MJ = pd.read_csv('MJ_1982_2018 _US_mass_shootings.csv')
df_MJ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 22 columns):
# case                                   99 non-null object
# location                               99 non-null object
# date                                   99 non-null object
# year                                   99 non-null int64
# summary                                99 non-null object
# Fatalities                             99 non-null int64
# Injured                                99 non-null int64
# total_victims                          99 non-null object
# Venue                                  99 non-null object
# Prior signs of mental health issues    99 non-null object
# Mental health - details                98 non-null object
# Weapons obtained legally               99 non-null object
# Where obtained                         98 non-null object
# Type of weapons                        99 non-null object
# Weapon details                         99 non-null object
# Race                                   99 non-null object
# Gender                                 99 non-null object
# Sources                                99 non-null object
# Mental Health Sources                  99 non-null object
# latitude                               99 non-null float64
# longitude                              99 non-null float64
# Type                                   99 non-null object
# dtypes: float64(2), int64(3), object(17)
# memory usage: 17.1+ KB

# %%
df_MJ['month'] = pd.DatetimeIndex(df_MJ['date']).month

# %%
df_MJ.hist(column = ['month'], bins = 12, figsize = (12,8), xlabelsize=13, ylabelsize =13)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efd66bc3f60>]],
#       dtype=object)

# %% [markdown]
# Clearly, histogram shows that there is no seasonality in indsicriminate shooting incidents. Chi-square test indicates the same

# %%
dat_MJ_num = df_MJ.groupby('month').count()['case']

# %%
avg_MJ = [dat_MJ_num.sum()/ len(dat_MJ_num)]*12

# %%
print ("probability of the observed shooings to be independent of the month is ",chisquare(dat_MJ_num, avg_MJ)[1])
# Out:
# probability of the observed shooings to be independent of the month is  0.81361053450126

# %% [markdown]
# Clearly, chi-square test also shows that there is no seasonality

# %% [markdown]
# ## Google trends data

# %% [markdown]
# search volume for keyword 'gun' was downloaded from google trends webpage: https://trends.google.com/trends/explore?date=2018-03-30%202018-04-30&geo=US&q=gun

# %%
df_goog = pd.read_csv('multiTimeline.csv')

# %%
df_goog.head()
# Out:
#      Month  gun
# 0  2004-01   41
# 1  2004-02   39
# 2  2004-03   40
# 3  2004-04   40
# 4  2004-05   37

# %%
df_goog['date'] = pd.DatetimeIndex(df_goog['Month'])

# %%
df_goog.set_index(['date'],inplace=True)

# %%
df_goog['gun'].plot(figsize=(15,15))
